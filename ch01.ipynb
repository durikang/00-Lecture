# %% [markdown]
# <a href="https://colab.research.google.com/github/durikang/00-Lecture/blob/master/ch01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## pd.DataFrame(data,index,columns)
import pandas as pd

data=[[67,93,91,88],
      [75,69,96,69],
      [75,81,74,82],
      [96,65,84,66],
      [79,70,76,75],
      [62,99,87,76]]
index=['홍길동','김나현','권보아','박효신','김범수','이효리']
columns=['국어','영어','수학','과학']

df = pd.DataFrame(data,index,columns)
# Out:
#         국어     영어     수학     과학
# 홍길동  False   True   True   True
# 김나현  False  False   True  False
# 권보아  False   True  False   True
# 박효신   True  False   True  False
# 김범수  False  False  False  False
# 이효리  False   True   True  False

# %%
## pd.Series(data=None, index = None)
data_k = [67,75,75,96,79,62]
index=['홍길동','김나현','권보아','박효신','김범수','이효리']
df1 = pd.Series(data=data_k,index= index)
df1

df1['80점 넘는 사람'] = df1.loc[df1>80]
df1
# Out:
# 홍길동                              67
# 김나현                              75
# 권보아                              75
# 박효신                              96
# 김범수                              79
# 이효리                              62
# 80점 넘는 사람    박효신    96
# dtype: int64
# dtype: object

# %%
data2 = [[67,93,91],
          [75,69,96],
          [75,81,74],
          [96,65,84]]
index = list('ABCD')
columns=['국어','영어','수학']

df2 = pd.DataFrame(data2,index,columns)
df2.iloc[1:3]
# Out:
#    국어  영어  수학
# B  75  69  96
# C  75  81  74
